# %% [markdown]
# <a href="https://colab.research.google.com/github/kSH-2021/PyTorchZeroToAll/blob/main/lec_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
