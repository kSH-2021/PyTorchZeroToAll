# %% [markdown]
# <a href="https://colab.research.google.com/github/kSH-2021/PyTorchZeroToAll/blob/main/lec_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch.autograd import Variable

x_data = [1.0, 2.0, 3.0]
y_data = [2.0, 4.0, 6.0]

w = Variable(torch.Tensor([1.0]), requires_grad=True) #Any random value
# tensor는 n차원 배열이다. requires_grad하면 추적한다.?
def forward(x):
  return w * x
def loss(x, y):
  y_pred = forward(x)
  return (y_pred - y) * (y_pred - y)
def gradient(x, y):
  return 2 * x * (x * w - y) #mse 미분한 식


# Before training
print("predict (before training)", 4, forward(4))
#다른 데이터에 적용할 수 있는 알고리즘 찾는 게 목표
#결국 적당한 w(가중치) 찾는 게 목표

# Training loop
l_sum =0
for epoch in range(100):
  for x_val, y_val in zip(x_data, y_data):
    l = loss(x_val, y_val) #오차 제곱: (예측값 - 실제y값)**2
    l.backward() #역전파. 손실값 계산..
    print("\tgrad: ", x_val, y_val, w.grad.data[0])
    w.data = w.data - 0.01 * w.grad.data #미분값과 같음
    w.grad.data.zero_() #0으로 만듦   w.grad.data.zero_() #0으로 만듦
        
    print("progress:", epoch, l.data[0])

# After training
print("predict(after training)", 4, forward(4).data[0])
## 17번째 시도 이후 loss 증가.
# Out:
# predict (before training) 4 tensor([4.], grad_fn=<MulBackward0>)
# 	grad:  1.0 2.0 tensor(-2.)
# progress: 0 tensor(1.)
# 	grad:  2.0 4.0 tensor(-7.8400)
# progress: 0 tensor(3.8416)
# 	grad:  3.0 6.0 tensor(-16.2288)
# progress: 0 tensor(7.3159)
# 	grad:  1.0 2.0 tensor(-1.4786)
# progress: 1 tensor(0.5466)
# 	grad:  2.0 4.0 tensor(-5.7962)
# progress: 1 tensor(2.0997)
# 	grad:  3.0 6.0 tensor(-11.9981)
# progress: 1 tensor(3.9988)
# 	grad:  1.0 2.0 tensor(-1.0932)
# progress: 2 tensor(0.2988)
# 	grad:  2.0 4.0 tensor(-4.2852)
# progress: 2 tensor(1.1477)
# 	grad:  3.0 6.0 tensor(-8.8704)
# progress: 2 tensor(2.1857)
# 	grad:  1.0 2.0 tensor(-0.8082)
# progress: 3 tensor(0.1633)
# 	grad:  2.0 4.0 tensor(-3.1681)
# progress: 3 tensor(0.6273)
# 	grad:  3.0 6.0 tensor(-6.5580)
# progress: 3 tensor(1.1946)
# 	grad:  1.0 2.0 tensor(-0.5975)
# progress: 4 tensor(0.0893)
# 	grad:  2.0 4.0 tensor(-2.3422)
# progress: 4 tensor(0.3429)
# 	grad:  3.0 6.0 tensor(-4.8484)
# ...
